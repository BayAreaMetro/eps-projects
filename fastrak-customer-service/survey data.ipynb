# %%
import pandas as pd

# %%
survey = pd.read_excel("/Users/smcnish/MTC/data/December_2017_Web_Survey2.xml")

survey =survey.rename(index=str, columns={survey.columns[0]: "date", survey.columns[1]: "purpose",
                                          survey.columns[2]: "task_completion", survey.columns[3]: "effort",
                                          survey.columns[4]: "satisfaction", survey.columns[5]: "recommendation",
                                          survey.columns[6]: "feedback"})

# %%
survey.head(10)
# Out:
#                  date            purpose task_completion            effort  \
# 0 2017-12-31 23:12:59  Register Toll Tag             Yes  Very High Effort
# 1 2017-12-31 23:02:03     Account Update             Yes   Very Low Effort
# 2 2017-12-31 23:00:13     Pay an Invoice             Yes           Neutral
# 3 2017-12-31 22:57:57     Account Update             Yes        Low Effort
# 4 2017-12-31 22:50:09     Account Update             Yes   Very Low Effort
# 5 2017-12-31 22:42:18     Account Update             Yes   Very Low Effort
# 6 2017-12-31 22:38:14     Account Update             Yes        Low Effort
# 7 2017-12-31 22:37:03     Account Update             Yes   Very Low Effort
# 8 2017-12-31 22:32:10     Account Update             Yes   Very Low Effort
# 9 2017-12-31 22:19:37     Account Update             Yes        Low Effort
#
#            satisfaction  recommendation  \
# 0        Unsatisfactory             0.0
# 1           Exceptional            10.0
# ...

# %%
# %matplotlib inline
survey.countpass.plot.hist()
